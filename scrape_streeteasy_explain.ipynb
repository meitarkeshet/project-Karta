# %% [markdown]
# # Scraping StreetEasy's historical data

# %% [markdown]
# StreetEasy (a brand and registered trademark of Zillow, Inc.) is New York City's leading real estate marketplace.
# The website displys a current rental (and sales) listings only - and does not allow access to past listings which are now off the market.
# And so, to get data on the website's past condition We will use the **'wayback machine'** to access a 'screenshot' at a past data.

# %% [markdown]
# ### We will focus on **Manhatten**

# %% [markdown]
# Our process will be:

# %% [markdown]
# - For each **month** in the years **2014-2019**:
#     - Search in the 'wayback machine' (a 'internetarchives.com' project) under the website: http://streeteasy.com/for-rent/manhattan.
#     - For each **page** in the first **10** pages:
#         - List all **links** to rentel listings on page
#         - For each **link** on a **page**:
#             - scrape info and append into mysql Dataset

# %% [markdown]
# ***

# %% [markdown]
# ### Import libraries

# %% [markdown]
# General

# %%
# for printing current time when crashes and waits
import time
import datetime

# for scraping htmls
from bs4 import BeautifulSoup

# to avoid getting blocked
import random

import requests  # for soup

import pandas as pd # for dataFrames

import re # for regex search
import lxml # better then html detection 
import cchardet # to assit in charecter detection

# %% [markdown]
# Webdriver specific

# %%
from selenium import webdriver

# in order to not expose our password we will use 'getpass'
import getpass
# To connect to mysql use:
from sqlalchemy import create_engine

# for opening the web browser

PATH = "C:\\Program Files (x86)\\chromedriver.exe" 
# -----------------------------> NOTICE: 1. did you download chromedriver? 2. is the location correct?
driver = webdriver.Chrome(PATH)

# for loading the page : start only after loading
from selenium.webdriver.chrome.options import Options

# %% [markdown]
# ***

# %% [markdown]
# # Functions

# %% [markdown]
# ## Utility functions:

# %% [markdown]
# TAKES a url for a webpage and RETURNS a list of links (for each rental proposal) on that page

# %%
def outisde_scrape_links(url):  
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')  
        
    page_link_lst = []
    for link in soup.findAll("div", {"class": "details-title"}) :
        page_link_lst.append("https://web.archive.org"+link.find("a")['href']) # find the link attached 
    return(page_link_lst)

# %% [markdown]
# TAKES a url of a single rental proposal including detaild information and RETURNS a single row'de dataFrame

# %%
def inside_scrape(url):
    print(url,'\n') # see current url proccesed 

    r = requests.get(url) 
    soup = BeautifulSoup(r.text, 'lxml') # read as lxml for faster encoding 
    
    # create an empty data Frame
    # ----------------------------------------

    df_single_search = pd.DataFrame()
    
    # error handling - initialize columns as nulls
    
    scrape_year, scrape_day, scrape_month, scrape_hour,  = 'NaN','NaN','NaN','NaN'
    description_short, description_long = 'NaN','NaN'
    price, rooms,amenities = 'NaN','NaN','NaN'
    zip_code, address = 'NaN','NaN' 
    days_on_market, price_history, lister = 'NaN','NaN','NaN'
    price_at_point, last_price_change ='NaN','NaN'

    # insert data to dataFrame
    # ----------------------------------------
    
    # 1. Price, Short description, Room description:
    details = soup.find("div", {"class": "details"})
   
    if details:
        # short description of the listing
        details_describe = details.find_all('span', attrs={'class':re.compile(r'detail_cell')})
        if details_describe:
            description_short = "".join(re.findall(r'\>(.*?)\<' , str(details_describe))) # DESC_SHORT > to file
        #print(description_short)
         # description of rooms
        details_a = details.find_all('span', attrs={'class':'nobreak'})
        if details_a:
            rooms = "".join(re.findall(r'\>(.*?)\<' , str(details_a))) # ROOMS > to df
    # the price asked:
        price = re.findall(r'(?=\$).+', str(details))[0]  # RENT PRICE > to df
    
    df_single_search['price'] = [price] # notice passing as list 
    df_single_search['des_short'] = [description_short] # notice passing as list 
    df_single_search['des_rooms'] = [rooms] # notice passing as list 
    

    # 2. Detailed description (by owner):
    describe_soup = soup.find("blockquote", {"class": "description_togglable hidden"})
    if describe_soup:
        description_long = describe_soup.get_text() # DESC_LONG > to file
    df_single_search['des_long'] = [description_long] # notice passing as list 

    # 3. Amenities included:
    amenities_soup = soup.find('div', attrs={'class':re.compile(r'amenities')})
    if amenities_soup:
        amenities = amenities_soup.get_text().replace("Amenities", "").replace("\n\n", " ")
    df_single_search['amenities'] = [amenities] # notice passing as list 

    # 4. Zip code, Address:
    address = soup.select_one('h2 ~ p')
    if address:
        address = address.get_text()
    # seperate address, city, zipcode
        address_dirty = "".join(re.findall(r'(?!  ).?', ''.join(address.split('\n'))))
        if address_dirty:
            address_dirty = address_dirty.split('  ')[0].replace(u'\xa0', u' ').split('  ') # the encoding ('utf-8') casuses space to be written as '\xa0'
            if len(address_dirty) == 2:
        # zip code
                if address_dirty[1]:
                    zip_code = re.findall(r'[0-9]*$', address_dirty[1].strip())[0]
        # address
                if address_dirty[0]:
                    address = address_dirty[0]
    else: # if the address is not specified - use the ad title
        address = soup.find('h1', attrs={'class':'building-title nd___highlighted'})
        if address:
            address = address.get_text()
    
    df_single_search['zip'] = [zip_code] # notice passing as list 
    df_single_search['address'] = [address] # notice passing as list 
    
    # 4. Days on the market, Last price change:
    facts_dirty = soup.select('h6 ~ *')
    if facts_dirty:
        for i in facts_dirty:
        # Days On Market
            #print(i.get_text(), "\n")
            #print("end\n")
            if "days on StreetEasy" in i.get_text():
                days_on_market = i.get_text().strip()

        # Last Price Change
            if "days ago" in i.get_text():
                last_price_change = i.get_text().strip()
                last_price_change = " ".join([i.strip() for i in last_price_change.split('\n')])
                
    df_single_search['last_price_change'] = [last_price_change] # notice passing as list 
    df_single_search['days_on_market'] = [days_on_market] # notice passing as list 


    # 5. Price history (date), Lister's (names), Price at date:
    price_change_dirty = soup.select('h2 ~ table')
     # Price change history
    if price_change_dirty:
        history_table = pd.read_html(str(price_change_dirty))[0].fillna(method='ffill', axis=0) # save into a pandas DataSet - fill NaN!
        if history_table.shape[1] == 3:
            print("\nhistory_table: \n",history_table)
            
            if not history_table.iloc[:,0].empty:
                price_history = "|".join(list(history_table.iloc[:,0])) # notice - before added 'str' line
                #print("\nprice_history: ", price_history)

            if not history_table.iloc[:,1].empty:
                lister = "|".join(list(history_table.iloc[:,1]))
                #print("\nlister: ", lister)

            if not history_table.iloc[:,2].empty:
                price_at_point = "|".join(list(history_table.iloc[:,2]))
    df_single_search['price_history'] = price_history
    df_single_search['lister'] = lister
    df_single_search['price_at_point'] = price_at_point
    
    # 7. when was the page archived - Year, Day, Month, Hour:
    archive_dates = re.findall(r'(?<=FILE ARCHIVED ON ).*(?=AND)' , str(soup))
    if archive_dates:
        archive_dates = archive_dates[0]
        print(archive_dates,"\n")
        scrape_hour = re.findall(r'\d\d:\d\d:\d\d' , archive_dates)[0].strip()
        scrape_year =  re.findall(r'\d{4}.*$' , archive_dates)[0].strip()
        scrape_day =  re.findall(r'\d+(?=,)' , archive_dates)[0].strip()
        scrape_month =  re.findall(r'(?<=\d\d:\d\d:\d\d).+?(?= )' , archive_dates)[0].strip()
    
    df_single_search['scrape_year'] = scrape_year
    df_single_search['scrape_day'] = scrape_day
    df_single_search['scrape_month'] = scrape_month
    df_single_search['scrape_hour'] = scrape_hour

    print(df_single_search) # show what was scraped
    return(df_single_search)

# %% [markdown]
# TAKES a url for a rental proposal, opens it and checks if the word *Hrm.* exist in the first h2 object (meaning the page *isn't* archived). Returns True / False

# %%
def check_archived(web_page):
    requests_session = requests.Session()
    try:
        r = requests_session.get(web_page, timeout=10.0)
        soup = BeautifulSoup(r.text, 'lxml') 
        top_h2 = soup.select_one('h2')
        if top_h2:
            top_h2 = top_h2.get_text()
            print (top_h2)
            if 'Hrm.' in top_h2:
                print("Page not archived")
                return (False)
            else:
                print("Page archived")
                return (True)
    except requests.Timeout as err:
        print(err)
        return(False)
    except requests.RequestException as err:
        print(err)
        return(False)
    return(False)

# %% [markdown]
# Takes a url for the first page and RETURNS the number pages that existed (even though we will only scrape 10)

# %%
def check_last_page_nbr(first_page):
    r = requests.get(first_page)
    soup = BeautifulSoup(r.text, 'html.parser')  
    last_page_num = soup.select('a:nth-last-child(2)')[-2].get_text()
    return (int(last_page_num))

# %% [markdown]
# ## MAIN FUNCTION

# %% [markdown]
# TAKES the title page of a of the zone (e.g Manhattan) in a specific date (e.g jan 2014) and RETURNS a dataFrame containting the rent listings from the first **10**  pages.

# %%
def scrape_moment(first_page, tmp_df_name):
    current_page_url = first_page # on the first round - use first page as current
    
    # create an empty dataFrame
    dfObj = pd.DataFrame(columns=['scrape_day','scrape_month','scrape_year',
                                  'scrape_hour','des_short', 'des_long', 'price', 'des_rooms', 'amenities',
                                  'zip', 'address', 'days_on_market', 'price_history', 'lister', 'price_at_point',
                                  'last_price_change'])
    
    #last_page_num = check_last_page_nbr(first_page) # how many pages existed in total (even though we only scrape the first 10)
    #last_page_num = 'NaN'
    #dfObj['page_pop_size'] = last_page_num

    scrape_page = current_page_url # on the first round - use first page as current
    page_list = list(range(2,11)) # scrape only 9 pages (after the first page)

    pages_success_scrape = set() # create an empty set to hold the number of pages that were succesfully scraped
    print (page_list)
    page_num = 1 
    while page_num < 10: # while there's pages left to scrape from the list (we remove a single page each round)
        page_link_lst = outisde_scrape_links(current_page_url) # get links on current page
        for link in page_link_lst:
            time.sleep(random.randint(10, 20)) # avoid getting blocked
            # check if the page was archived
            if check_archived(link):
                dfObj = dfObj.append(inside_scrape(link)) 
                pages_success_scrape.add(scrape_page) # add to set
            print("Scraped: ",page_num, " out of : 10") # to see where we are in the scrape

        scrape_page = random.choice(page_list) # select a random page number value from the list of posible pages
        print("\nLooking into: ",scrape_page)
        page_list.remove(scrape_page) # take out p. number of the current scraped page from the list of possible pages

        dfObj.to_sql(tmp_df_name, engine, index=False, if_exists='append') # push to sql
        print("\n", current_page_url,"\n")
        page_num = page_num+1 # for counting pages scraped
        #current_page_url = str(first_page)+"?page={}".format(page_num)# change to the next page
        current_page_url = str(first_page)+"?page={}".format(scrape_page)# change to the next page
        
        print("\nafter:", current_page_url,"\n")
        print("\nScraped the following pages: ",pages_success_scrape)
        print("\nWhich makes a total of :",len(pages_success_scrape))
        time.sleep(random.randint(10, 120)) # avoid getting blocked

    return (dfObj)

# %% [markdown]
# ## Connect to my local SQL server

# %%
hostname = "localhost"
username = "root"
password = getpass.getpass()
database = "karta"
engine = create_engine(f"mysql+pymysql://{username}:{password}@{hostname}/{database}")
# Out:
#  ·············

# %% [markdown]
# The dataFrame that we use will have the following columns:

# %%
base_df = pd.DataFrame(columns=['scrape_day','scrape_month','scrape_year','scrape_hour','des_short',
                                'des_long', 'price', 'des_rooms', 'amenities', 'zip', 'address',
                                'days_on_market', 'price_history', 'lister', 'price_at_point','last_price_change'])

# %% [markdown]
# # Run

# %% [markdown]
# Define the years and months we're intrested in

# %%
year_lst = ['2019']
#month_lst = ['04','05','06','07','08','09','10','11','12']
month_lst = ['01','02','03','04','05','06','07','08','09','10','11','12']

# %% [markdown]
# Run the code for each year and month

# %%
for year in year_lst:
    time.sleep(random.randint(180, 300)) # avoid getting blocked
    for month in month_lst:
        time.sleep(random.randint(180, 300)) # avoid getting blocked
        print(year) # see on which year we're on
        print(month) # see on which month we're on
        # clear / create dataFrame (in sql):
        tmp_df_name = f'ann_rent_{year}_manhattan_{month}'
        base_df.to_sql(tmp_df_name, engine, index=False, if_exists='replace')  
        # change url according to month and year
        url = f'https://web.archive.org/web/{year}{month}/http://streeteasy.com/for-rent/manhattan'
        print(f'{url}\n')
        #push current month (and year) to sql
        scrape_moment(url, tmp_df_name)
# Out:
# 2019
# 01
# https://web.archive.org/web/201901/http://streeteasy.com/for-rent/manhattan
#
# [2, 3, 4, 5, 6, 7, 8, 9, 10]
#
# Looking into:  6
#
#  https://web.archive.org/web/201901/http://streeteasy.com/for-rent/manhattan
#
#
# after: https://web.archive.org/web/201901/http://streeteasy.com/for-rent/manhattan?page=6
#
#
# Scraped the following pages:  set()
#
# Which makes a total of : 0
#
# Looking into:  7
#
#  https://web.archive.org/web/201901/http://streeteasy.com/for-rent/manhattan?page=6
#
#
# after: https://web.archive.org/web/201901/http://streeteasy.com/for-rent/manhattan?page=7
#
#
# Scraped the following pages:  set()
#
# Which makes a total of : 0
#
# Looking into:  2
#
#  https://web.archive.org/web/201901/http://streeteasy.com/for-rent/manhattan?page=7
#
#
# after: https://web.archive.org/web/201901/http://streeteasy.com/for-rent/manhattan?page=2
#
#
# Scraped the following pages:  set()
#
# Which makes a total of : 0
#
# Looking into:  10
#
#  https://web.archive.org/web/201901/http://streeteasy.com/for-rent/manhattan?page=2
#
#
# after: https://web.archive.org/web/201901/http://streeteasy.com/for-rent/manhattan?page=10
#
#
# Scraped the following pages:  set()
#
# Which makes a total of : 0
# Hrm.
# Page not archived
# Scraped:  5  out of : 10
# Pardon Our Interruption
# Page archived
# https://web.archive.org/web/20170702183051/http://streeteasy.com/building/city-and-suburban-homes-company-av-519-east-78-street-new_york/1g
#
# 02:48:13 Jul 02, 2017
#
#   price des_short des_rooms des_long amenities  zip  \
# 0   NaN       NaN       NaN      NaN       NaN  NaN
#
#                                              address last_price_change  \
# 0  As you were browsing, something about your bro...               NaN
#
#   days_on_market price_history lister price_at_point scrape_year scrape_day  \
# 0            NaN           NaN    NaN            NaN        2017         02
#
#   scrape_month scrape_hour
# 0          Jul    02:48:13
# Scraped:  5  out of : 10
# Pardon Our Interruption
# Page archived
# https://web.archive.org/web/20170702183051/http://streeteasy.com/building/517-east-77-street-/2l
#
# 06:03:02 Jul 09, 2017
#
#   price des_short des_rooms des_long amenities  zip  \
# 0   NaN       NaN       NaN      NaN       NaN  NaN
#
#                                              address last_price_change  \
# 0  As you were browsing, something about your bro...               NaN
#
#   days_on_market price_history lister price_at_point scrape_year scrape_day  \
# 0            NaN           NaN    NaN            NaN        2017         09
#
#   scrape_month scrape_hour
# 0          Jul    06:03:02
# Scraped:  5  out of : 10
# Hrm.
# Page not archived
# Scraped:  5  out of : 10
# Hrm.
# Page not archived
# Scraped:  5  out of : 10
# Pardon Our Interruption
# Page archived
# https://web.archive.org/web/20170702183051/http://streeteasy.com/building/new-york-tower/10k
#
# 06:25:13 Jul 09, 2017
#
#   price des_short des_rooms des_long amenities  zip  \
# 0   NaN       NaN       NaN      NaN       NaN  NaN
#
#                                              address last_price_change  \
# 0  As you were browsing, something about your bro...               NaN
#
#   days_on_market price_history lister price_at_point scrape_year scrape_day  \
# 0            NaN           NaN    NaN            NaN        2017         09
#
#   scrape_month scrape_hour
# 0          Jul    06:25:13
# Scraped:  5  out of : 10
# Pardon Our Interruption
# Page archived
# https://web.archive.org/web/20170702183051/http://streeteasy.com/building/new-york-tower/29e
#
# 04:44:45 Jul 09, 2017
#
#   price des_short des_rooms des_long amenities  zip  \
# 0   NaN       NaN       NaN      NaN       NaN  NaN
#
#                                              address last_price_change  \
# 0  As you were browsing, something about your bro...               NaN
#
#   days_on_market price_history lister price_at_point scrape_year scrape_day  \
# 0            NaN           NaN    NaN            NaN        2017         09
#
#   scrape_month scrape_hour
# 0          Jul    04:44:45
# Scraped:  5  out of : 10
# Pardon Our Interruption
# Page archived
# https://web.archive.org/web/20170702183051/http://streeteasy.com/building/new-york-tower/31m
#
# 08:05:05 Jul 17, 2017
#
#   price des_short des_rooms des_long amenities  zip  \
# 0   NaN       NaN       NaN      NaN       NaN  NaN
#
#                                              address last_price_change  \
# 0  As you were browsing, something about your bro...               NaN
#
#   days_on_market price_history lister price_at_point scrape_year scrape_day  \
# 0            NaN           NaN    NaN            NaN        2017         17
#
#   scrape_month scrape_hour
# 0          Jul    08:05:05
# Scraped:  5  out of : 10
# Hrm.
# Page not archived
# Scraped:  5  out of : 10
# HTTPSConnectionPool(host='web.archive.org', port=443): Read timed out. (read timeout=10.0)
# Scraped:  5  out of : 10
# Hrm.
# Page not archived
# Scraped:  5  out of : 10
# Pardon Our Interruption
# Page archived
# https://web.archive.org/web/20170702183051/http://streeteasy.com/building/399-east-78-street-new_york/5c
#
# 12:44:58 Jul 07, 2017
#
#   price des_short des_rooms des_long amenities  zip  \
# 0   NaN       NaN       NaN      NaN       NaN  NaN
#
#                                              address last_price_change  \
# 0  As you were browsing, something about your bro...               NaN
#
#   days_on_market price_history lister price_at_point scrape_year scrape_day  \
# 0            NaN           NaN    NaN            NaN        2017         07
#
#   scrape_month scrape_hour
# 0          Jul    12:44:58
# Scraped:  5  out of : 10
# Pardon Our Interruption
# Page archived
# https://web.archive.org/web/20170702183051/http://streeteasy.com/building/38nine-condominium/4c
#
# 01:46:36 Jul 09, 2017
#
#   price des_short des_rooms des_long amenities  zip  \
# 0   NaN       NaN       NaN      NaN       NaN  NaN
#
#                                              address last_price_change  \
# 0  As you were browsing, something about your bro...               NaN
#
#   days_on_market price_history lister price_at_point scrape_year scrape_day  \
# 0            NaN           NaN    NaN            NaN        2017         09
#
#   scrape_month scrape_hour
# 0          Jul    01:46:36
# Scraped:  5  out of : 10
# Pardon Our Interruption
# Page archived
# https://web.archive.org/web/20170702183051/http://streeteasy.com/building/87-bowery-new_york/702
#
# 01:39:29 Jul 26, 2017
#
#   price des_short des_rooms des_long amenities  zip  \
# 0   NaN       NaN       NaN      NaN       NaN  NaN
#
#                                              address last_price_change  \
# 0  As you were browsing, something about your bro...               NaN
#
#   days_on_market price_history lister price_at_point scrape_year scrape_day  \
# 0            NaN           NaN    NaN            NaN        2017         26
#
#   scrape_month scrape_hour
# 0          Jul    01:39:29
# Scraped:  5  out of : 10
#
# Looking into:  8
#
#  https://web.archive.org/web/201901/http://streeteasy.com/for-rent/manhattan?page=10
#
#
# after: https://web.archive.org/web/201901/http://streeteasy.com/for-rent/manhattan?page=8
#
#
# Scraped the following pages:  {10}
#
# Which makes a total of : 1
# Listing Facts
# Page archived
# https://web.archive.org/web/20161021052141/http://streeteasy.com/building/the-colorado/12a?featured=1
#
#
# history_table:
#              0                               1         2
# 0  07/22/2016      Listed by Nancy Packes Inc    $5,623
# 1  07/29/2016  Listing is no longer available    $5,623
# 2  10/06/2016   Re-listed by Nancy Packes Inc    $6,610
# 3  10/06/2016          Price increased by 18%  ↑ $6,610
# 00:56:06 Oct 26, 2016
#
#     price                 des_short                  des_rooms  \
# 0  $6,610  4 rooms, 2 beds, 2 baths  Rental Unit, in Yorkville
#
#                                             des_long  \
# 0  \n  Includes 2 months free on a 14 month lease...
#
#                                            amenities    zip  \
# 0  \nHighlights    Doorman            This highli...  10028
#
#                              address             last_price_change  \
# 0  The Colorado 201 East 86th Street  ↑ 12.99% 19 days ago by $987
#
#           days_on_market                                price_history  \
# 0  26 days on StreetEasy  07/22/2016|07/29/2016|10/06/2016|10/06/2016
#
#                                               lister  \
# 0  Listed by Nancy Packes Inc|Listing is no longe...
#
#                   price_at_point scrape_year scrape_day scrape_month  \
# 0  $5,623|$5,623|$6,610|↑ $6,610        2016         26          Oct
#
#   scrape_hour
# 0    00:56:06
# Scraped:  6  out of : 10
# Hrm.
# Page not archived
# Scraped:  6  out of : 10
# Hrm.
# Page not archived
# Scraped:  6  out of : 10
# Hrm.
# Page not archived
# Scraped:  6  out of : 10
# Hrm.
# Page not archived
# Scraped:  6  out of : 10
# Listing Facts
# Page archived
# https://web.archive.org/web/20161021052141/http://streeteasy.com/building/309-west-30-street-new_york/7d
#
#
# history_table:
#              0                                                  1         2
# 0  03/30/2012            Previously Listed by B and L Management    $1,985
# 1  04/10/2012  B and L Management Listing is no longer available    $1,985
# 2  04/30/2013            Previously Listed by B and L Management    $2,150
# 3  06/10/2013  B and L Management Listing is no longer available    $2,150
# 4  10/20/2016                       Previously Listed by Compass    $2,750
# 5  11/21/2016             Compass Listing is no longer available    $2,750
# 6  11/22/2016                                      Listed by MNS    $3,022
# 7  12/07/2016                              Price increased by 2%  ↑ $3,069
# 13:56:36 Jan 06, 2017
#
#     price       des_short                     des_rooms  \
# 0  $3,069  studio, 1 bath  Rental Unit, in Hudson Yards
#
#                                             des_long  \
# 0  \n  *NO FEE, ONE MONTH FREESpacious Studio - C...
#
#                                           amenities    zip  \
# 0  \nHighlights            Pets Allowed \n           10001
#
#                  address last_price_change         days_on_market  \
# 0   309 West 30th Street               NaN  45 days on StreetEasy
#
#                                        price_history  \
# 0  03/30/2012|04/10/2012|04/30/2013|06/10/2013|10...
#
#                                               lister  \
# 0  Previously Listed by B and L Management|B and ...
#
#                                       price_at_point scrape_year scrape_day  \
# 0  $1,985|$1,985|$2,150|$2,150|$2,750|$2,750|$3,0...        2017         06
#
#   scrape_month scrape_hour
# 0          Jan    13:56:36
# Scraped:  6  out of : 10
# Hrm.
# Page not archived
# Scraped:  6  out of : 10
# Listing Facts
# Page archived
# https://web.archive.org/web/20161021052141/http://streeteasy.com/building/434-lenox-avenue-manhattan/3a
#
#
# history_table:
#              0                                                  1       2
# 0  05/18/2016           Previously Listed by Keller Williams NYC  $2,700
# 1  09/20/2016                      Listed by Keller Williams NYC  $2,650
# 2  09/20/2016  Keller Williams NYC Listing is no longer avail...  $2,700
# 18:53:35 Oct 18, 2016
#
#     price                des_short                       des_rooms des_long  \
# 0  $2,650  4 rooms, 2 beds, 1 bath  Rental Unit, in Central Harlem      NaN
#
#                                   amenities    zip            address  \
# 0  \nHighlights    Washer/Dryer In-Unit  \n  10037   434 Lenox Avenue
#
#   last_price_change         days_on_market                     price_history  \
# 0               NaN  28 days on StreetEasy  05/18/2016|09/20/2016|09/20/2016
#
#                                               lister        price_at_point  \
# 0  Previously Listed by Keller Williams NYC|Liste...  $2,700|$2,650|$2,700
#
#   scrape_year scrape_day scrape_month scrape_hour
# 0        2016         18          Oct    18:53:35
# Scraped:  6  out of : 10
# Hrm.
# Page not archived
# Scraped:  6  out of : 10
# Listing Facts
# Page archived
# https://web.archive.org/web/20161021052141/http://streeteasy.com/building/226-east-12-street-new_york/rental/1913953
#
#
# history_table:
#              0                                                  1       2
# 0  01/28/2009          Previously Listed by Brown Harris Stevens  $2,300
# 1  04/07/2009       Off market temporarily Last priced at $2,400  $2,100
# 2  10/07/2009          Previously Listed by Brown Harris Stevens  $2,400
# 3  02/08/2010  Brown Harris Stevens Listing rented Last price...  $1,800
# 4  08/19/2016                       Also Listed by Bond New York  $2,950
# 5  08/31/2016           Previously Listed by Keller Williams NYC  $2,950
# 6  10/20/2016                      Listed by Keller Williams NYC  $2,849
# 7  10/20/2016  Keller Williams NYC Listing is no longer avail...  $2,849
# 01:35:17 Oct 26, 2016
#
#     price               des_short               des_rooms des_long  \
# 0  $2,849  3 rooms, 1 bed, 1 bath  Co-op, in East Village      NaN
#
#                                            amenities    zip  \
# 0  \nHighlights    Cats and Dogs Allowed         ...  10003
#
#                  address last_price_change        days_on_market  \
# 0   226 East 12th Street               NaN  5 days on StreetEasy
#
#                                        price_history  \
# 0  01/28/2009|04/07/2009|10/07/2009|02/08/2010|08...
#
#                                               lister  \
# 0  Previously Listed by Brown Harris Stevens|Off ...
#
#                                       price_at_point scrape_year scrape_day  \
# 0  $2,300|$2,100|$2,400|$1,800|$2,950|$2,950|$2,8...        2016         26
#
#   scrape_month scrape_hour
# 0          Oct    01:35:17
# Scraped:  6  out of : 10
# Listing Facts
# Page archived
# https://web.archive.org/web/20161021052141/http://streeteasy.com/building/192-claremont-avenue-manhattan/rental/1913954
#
#
# history_table:
#              0                                                  1       2
# 0  06/06/2014                Previously Listed by OGI Management  $4,500
# 1  07/16/2014  OGI Management Listing rented Last priced at $...  $4,000
# 2  07/29/2016           Previously Listed by Keller Williams NYC  $4,400
# 3  08/05/2016         Also Listed by Veritas Property Management  $4,500
# 4  09/15/2016           Previously Listed by Keller Williams NYC  $3,995
# 5  09/15/2016  Keller Williams NYC Listing is no longer avail...  $4,000
# 6  10/20/2016                      Listed by Keller Williams NYC  $3,495
# 7  10/20/2016  Keller Williams NYC Listing is no longer avail...  $3,495
# 14:02:00 Nov 06, 2016
#
#     price                 des_short                      des_rooms des_long  \
# 0  $3,495  6 rooms, 4 beds, 2 baths  Condo, in Morningside Heights      NaN
#
#                          amenities    zip                address  \
# 0   \nBuilding  \nLive-in Super     10027   192 Claremont Avenue
#
#   last_price_change         days_on_market  \
# 0               NaN  17 days on StreetEasy
#
#                                        price_history  \
# 0  06/06/2014|07/16/2014|07/29/2016|08/05/2016|09...
#
#                                               lister  \
# 0  Previously Listed by OGI Management|OGI Manage...
#
#                                       price_at_point scrape_year scrape_day  \
# 0  $4,500|$4,000|$4,400|$4,500|$3,995|$4,000|$3,4...        2016         06
#
#   scrape_month scrape_hour
# 0          Nov    14:02:00
# Scraped:  6  out of : 10
# Listing Facts
# Page archived
# https://web.archive.org/web/20161021052141/http://streeteasy.com/building/665-west-160-street-manhattan/6a
#
#
# history_table:
#              0                                                  1         2
# 0  07/29/2015                 Previously Listed by Citi Habitats    $3,400
# 1  09/29/2015  Citi Habitats Listing rented Last priced at $3...    $3,195
# 2  07/29/2016           Previously Listed by Keller Williams NYC    $3,495
# 3  09/15/2016                      Listed by Keller Williams NYC    $3,295
# 4  09/15/2016  Keller Williams NYC Listing is no longer avail...    $3,295
# 5  10/02/2016                              Price decreased by 4%  ↓ $3,150
# 00:24:44 Oct 07, 2016
#
#     price                 des_short                           des_rooms  \
# 0  $3,150  6 rooms, 4 beds, 2 baths  Rental Unit, in Washington Heights
#
#   des_long                                      amenities    zip  \
# 0      NaN  \nHighlights    Elevator     Pets Allowed  \n  10032
#
#                   address          last_price_change         days_on_market  \
# 0   665 West 160th Street  ↓ 4.4% 4 days ago by $145  21 days on StreetEasy
#
#                                        price_history  \
# 0  07/29/2015|09/29/2015|07/29/2016|09/15/2016|09...
#
#                                               lister  \
# 0  Previously Listed by Citi Habitats|Citi Habita...
#
#                                 price_at_point scrape_year scrape_day  \
# 0  $3,400|$3,195|$3,495|$3,295|$3,295|↓ $3,150        2016         07
#
#   scrape_month scrape_hour
# 0          Oct    00:24:44
# Scraped:  6  out of : 10
# Hrm.
# Page not archived
# Scraped:  6  out of : 10
# Listing Facts
# Page archived
# https://web.archive.org/web/20161021052141/http://streeteasy.com/building/john-h-caroline-iselin-residence/3c
#
#
# history_table:
#              0                                                  1       2
# 0  03/13/2012       Previously Listed by Plaza Real Estate Group  $2,500
# 1  05/02/2012  Plaza Real Estate Group Listing rented Last pr...  $2,400
# 2  10/20/2016       Previously Listed by Plaza Real Estate Group  $2,900
# 3  11/14/2016       Previously Listed by Plaza Real Estate Group  $2,700
# 4  11/14/2016  Plaza Real Estate Group Listing is no longer a...  $2,700
# 5  12/09/2016             Plaza Real Estate Group Listing rented  $2,700
# 6  01/19/2017          Previously Listed by Brown Harris Stevens  $2,695
# 7  02/23/2017  Brown Harris Stevens Listing is no longer avai...  $2,695
# 8  02/24/2017                     Listed by Brown Harris Stevens  $2,695
# 13:06:39 Feb 25, 2017
#
#     price                des_short                  des_rooms des_long  \
# 0  $2,695  2 rooms, studio, 1 bath  Co-op, in Upper East Side      NaN
#
#                                  amenities    zip  \
# 0   \nOutdoor Space \nCourtyard\nGarden     10075
#
#                                              address last_price_change  \
# 0  JOHN H.& CAROLINE ISELIN RESIDENCE 59 East 79t...               NaN
#
#   days_on_market                                      price_history  \
# 0            NaN  03/13/2012|05/02/2012|10/20/2016|11/14/2016|11...
#
#                                               lister  \
# 0  Previously Listed by Plaza Real Estate Group|P...
#
#                                       price_at_point scrape_year scrape_day  \
# 0  $2,500|$2,400|$2,900|$2,700|$2,700|$2,700|$2,6...        2017         25
#
#   scrape_month scrape_hour
# 0          Feb    13:06:39
# Scraped:  6  out of : 10
#
# Looking into:  3
#
#  https://web.archive.org/web/201901/http://streeteasy.com/for-rent/manhattan?page=8
#
#
# after: https://web.archive.org/web/201901/http://streeteasy.com/for-rent/manhattan?page=3
#
#
# Scraped the following pages:  {8, 10}
#
# Which makes a total of : 2
#
# Looking into:  5
#
#  https://web.archive.org/web/201901/http://streeteasy.com/for-rent/manhattan?page=3
#
#
# after: https://web.archive.org/web/201901/http://streeteasy.com/for-rent/manhattan?page=5
#
#
# Scraped the following pages:  {8, 10}
#
# Which makes a total of : 2
#
# Looking into:  9
#
#  https://web.archive.org/web/201901/http://streeteasy.com/for-rent/manhattan?page=5
#
#
# after: https://web.archive.org/web/201901/http://streeteasy.com/for-rent/manhattan?page=9
#
#
# Scraped the following pages:  {8, 10}
#
# Which makes a total of : 2
# Pardon Our Interruption
# Page archived
# https://web.archive.org/web/20170809010827/http://streeteasy.com/building/the-hermitage/phb
#
# 13:53:38 Jul 30, 2017
#
#   price des_short des_rooms des_long amenities  zip  \
# 0   NaN       NaN       NaN      NaN       NaN  NaN
#
#                                              address last_price_change  \
# 0  As you were browsing, something about your bro...               NaN
#
#   days_on_market price_history lister price_at_point scrape_year scrape_day  \
# 0            NaN           NaN    NaN            NaN        2017         30
#
#   scrape_month scrape_hour
# 0          Jul    13:53:38
# Scraped:  9  out of : 10
#
#               Ready to see this place in person?
#
#               Get in touch with an agent.
#
# Page archived
# https://web.archive.org/web/20170809010827/http://streeteasy.com/building/647-east-14-street-new_york/0ma
#
#
# history_table:
#               0                                                  1         2
# 0   12/13/2013    Previously Listed by StuyTown Property Services    $3,549
# 1   12/20/2013  StuyTown Property Services Listing is no longe...    $3,549
# 2   04/08/2014    Previously Listed by StuyTown Property Services    $5,035
# 3   04/30/2014    Previously Listed by StuyTown Property Services    $4,840
# 4   04/30/2014  StuyTown Property Services Listing is no longe...    $4,840
# 5   05/22/2014  StuyTown Property Services Listing is no longe...    $4,790
# 6   02/16/2017    Previously Listed by StuyTown Property Services    $3,967
# 7   03/04/2017  StuyTown Property Services Listing is no longe...    $3,902
# 8   07/20/2017               Listed by StuyTown Property Services    $4,682
# 9   07/22/2017                              Price increased by 1%  ↑ $4,722
# 10  07/24/2017                              Price increased by 3%  ↑ $4,862
# 11  07/26/2017                              Price decreased by 2%  ↓ $4,757
# 12  07/27/2017                              Price decreased by 3%  ↓ $4,622
# 13  07/28/2017                              Price decreased by 1%  ↓ $4,592
# 14  07/29/2017                              Price decreased by 1%  ↓ $4,562
# 15  07/31/2017                              Price increased by 3%  ↑ $4,697
# 10:23:23 Aug 07, 2017
#
#     price                                      des_short  \
# 0  $4,697  943 ft², $59 per ft², 2 rooms, 3 beds, 1 bath
#
#                              des_rooms des_long  \
# 0  Rental Unit, in Stuyvesant Town/PCV      NaN
#
#                                  amenities  zip  \
# 0   \nBuilding  \nVirtual Doorman\n     \n  NaN
#
#                             address last_price_change days_on_market  \
# 0  \n\nComplex: Stuyvesant Town\n\n               NaN            NaN
#
#                                        price_history  \
# 0  12/13/2013|12/20/2013|04/08/2014|04/30/2014|04...
#
#                                               lister  \
# 0  Previously Listed by StuyTown Property Service...
#
#                                       price_at_point scrape_year scrape_day  \
# 0  $3,549|$3,549|$5,035|$4,840|$4,840|$4,790|$3,9...        2017         07
#
#   scrape_month scrape_hour
# 0          Aug    10:23:23
# Scraped:  9  out of : 10
# Hrm.
# Page not archived
# Scraped:  9  out of : 10
# Pardon Our Interruption
# Page archived
# https://web.archive.org/web/20170809010827/http://streeteasy.com/building/95-wall-street-new_york/518
#
# 13:55:11 Aug 13, 2017
#
#   price des_short des_rooms des_long amenities  zip  \
# 0   NaN       NaN       NaN      NaN       NaN  NaN
#
#                                              address last_price_change  \
# 0  As you were browsing, something about your bro...               NaN
#
#   days_on_market price_history lister price_at_point scrape_year scrape_day  \
# 0            NaN           NaN    NaN            NaN        2017         13
#
#   scrape_month scrape_hour
# 0          Aug    13:55:11
# Scraped:  9  out of : 10
# Pardon Our Interruption
# Page archived
# https://web.archive.org/web/20170809010827/http://streeteasy.com/building/95-wall-street-new_york/1519
#
# 12:36:53 Aug 13, 2017
#
#   price des_short des_rooms des_long amenities  zip  \
# 0   NaN       NaN       NaN      NaN       NaN  NaN
#
#                                              address last_price_change  \
# 0  As you were browsing, something about your bro...               NaN
#
#   days_on_market price_history lister price_at_point scrape_year scrape_day  \
# 0            NaN           NaN    NaN            NaN        2017         13
#
#   scrape_month scrape_hour
# 0          Aug    12:36:53
# Scraped:  9  out of : 10
# Listing Facts
# Page archived
# https://web.archive.org/web/20170809010827/http://streeteasy.com/building/95-wall-street-new_york/1007
#
#
# history_table:
#              0                                                  1         2
# 0  10/13/2013                           Previously Listed by UDR    $7,123
# 1  12/10/2013  UDR Listing is no longer available Last priced...    $7,941
# 2  11/06/2014                                      Listed by UDR    $5,659
# 3  12/10/2014                              Price decreased by 2%  ↓ $5,559
# 05:56:30 Dec 21, 2014
#
#     price                                des_short  \
# 0  $5,559  1,079 ft², $61 per ft², 2 beds, 2 baths
#
#                             des_rooms des_long  \
# 0  Rental Unit, in Financial District      NaN
#
#                                            amenities    zip         address  \
# 0   \nBuilding  \nBike Room\nConcierge\nDoorman\n...  10005  95 Wall Street
#
#              last_price_change         days_on_market  \
# 0  ↓ 1.77% 11 days ago by $100  45 days on StreetEasy
#
#                                  price_history  \
# 0  10/13/2013|12/10/2013|11/06/2014|12/10/2014
#
#                                               lister  \
# 0  Previously Listed by UDR|UDR Listing is no lon...
#
#                   price_at_point scrape_year scrape_day scrape_month  \
# 0  $7,123|$7,941|$5,659|↓ $5,559        2014         21          Dec
#
#   scrape_hour
# 0    05:56:30
# Scraped:  9  out of : 10
# Pardon Our Interruption
# Page archived
# https://web.archive.org/web/20170809010827/http://streeteasy.com/building/207-east-37-street-new_york/6
#
# 08:38:05 Aug 24, 2017
#
#   price des_short des_rooms des_long amenities  zip  \
# 0   NaN       NaN       NaN      NaN       NaN  NaN
#
#                                              address last_price_change  \
# 0  As you were browsing, something about your bro...               NaN
#
#   days_on_market price_history lister price_at_point scrape_year scrape_day  \
# 0            NaN           NaN    NaN            NaN        2017         24
#
#   scrape_month scrape_hour
# 0          Aug    08:38:05
# Scraped:  9  out of : 10
# Pardon Our Interruption
# Page archived
# https://web.archive.org/web/20170809010827/http://streeteasy.com/building/95-wall-street-new_york/523
#
# 06:45:04 Aug 17, 2017
#
#   price des_short des_rooms des_long amenities  zip  \
# 0   NaN       NaN       NaN      NaN       NaN  NaN
#
#                                              address last_price_change  \
# 0  As you were browsing, something about your bro...               NaN
#
#   days_on_market price_history lister price_at_point scrape_year scrape_day  \
# 0            NaN           NaN    NaN            NaN        2017         17
#
#   scrape_month scrape_hour
# 0          Aug    06:45:04
# Scraped:  9  out of : 10
# Pardon Our Interruption
# Page archived
# https://web.archive.org/web/20170809010827/http://streeteasy.com/building/790-9-avenue-new_york/4a
#
# 08:45:47 Aug 12, 2017
#
#   price des_short des_rooms des_long amenities  zip  \
# 0   NaN       NaN       NaN      NaN       NaN  NaN
#
#                                              address last_price_change  \
# 0  As you were browsing, something about your bro...               NaN
#
#   days_on_market price_history lister price_at_point scrape_year scrape_day  \
# 0            NaN           NaN    NaN            NaN        2017         12
#
#   scrape_month scrape_hour
# 0          Aug    08:45:47
# Scraped:  9  out of : 10
# Scraped:  9  out of : 10
# Building
# Page archived
# https://web.archive.org/web/20170809010827/http://streeteasy.com/building/784-columbus-avenue-new_york/14k
#
# 01:46:31 Sep 30, 2016
#
#   price des_short des_rooms des_long amenities    zip               address  \
# 0   NaN       NaN       NaN      NaN       NaN  10025   784 Columbus Avenue
#
#   last_price_change days_on_market price_history lister price_at_point  \
# 0               NaN            NaN           NaN    NaN            NaN
#
#   scrape_year scrape_day scrape_month scrape_hour
# 0        2016         30          Sep    01:46:31
# Scraped:  9  out of : 10
# Pardon Our Interruption
# Page archived
# https://web.archive.org/web/20170809010827/http://streeteasy.com/building/soho-court/1007
#
# 08:50:08 Aug 12, 2017
#
#   price des_short des_rooms des_long amenities  zip  \
# 0   NaN       NaN       NaN      NaN       NaN  NaN
#
#                                              address last_price_change  \
# 0  As you were browsing, something about your bro...               NaN
#
#   days_on_market price_history lister price_at_point scrape_year scrape_day  \
# 0            NaN           NaN    NaN            NaN        2017         12
#
#   scrape_month scrape_hour
# 0          Aug    08:50:08
# Scraped:  9  out of : 10
# Scraped:  9  out of : 10
# Pardon Our Interruption
# Page archived
# https://web.archive.org/web/20170809010827/http://streeteasy.com/building/319-east-53-street-new_york/2f
#
# 05:05:49 Aug 12, 2017
#
#   price des_short des_rooms des_long amenities  zip  \
# 0   NaN       NaN       NaN      NaN       NaN  NaN
#
#                                              address last_price_change  \
# 0  As you were browsing, something about your bro...               NaN
#
#   days_on_market price_history lister price_at_point scrape_year scrape_day  \
# 0            NaN           NaN    NaN            NaN        2017         12
#
#   scrape_month scrape_hour
# 0          Aug    05:05:49
# Scraped:  9  out of : 10
#
# Looking into:  4
#
#  https://web.archive.org/web/201901/http://streeteasy.com/for-rent/manhattan?page=9
#
#
# after: https://web.archive.org/web/201901/http://streeteasy.com/for-rent/manhattan?page=4
#
#
# Scraped the following pages:  {8, 9, 10}
#
# Which makes a total of : 3
# 2019
# 02
# https://web.archive.org/web/201902/http://streeteasy.com/for-rent/manhattan
#
# [2, 3, 4, 5, 6, 7, 8, 9, 10]
#
# Looking into:  3
#
#  https://web.archive.org/web/201902/http://streeteasy.com/for-rent/manhattan
#
#
# after: https://web.archive.org/web/201902/http://streeteasy.com/for-rent/manhattan?page=3
#
#
# Scraped the following pages:  set()
#
# Which makes a total of : 0
#
# Looking into:  7
#
#  https://web.archive.org/web/201902/http://streeteasy.com/for-rent/manhattan?page=3
#
#
# after: https://web.archive.org/web/201902/http://streeteasy.com/for-rent/manhattan?page=7
#
#
# Scraped the following pages:  set()
#
# Which makes a total of : 0
#
# Looking into:  2
#
#  https://web.archive.org/web/201902/http://streeteasy.com/for-rent/manhattan?page=7
#
#
# after: https://web.archive.org/web/201902/http://streeteasy.com/for-rent/manhattan?page=2
#
#
# Scraped the following pages:  set()
#
# Which makes a total of : 0
#
# Looking into:  9
#
#  https://web.archive.org/web/201902/http://streeteasy.com/for-rent/manhattan?page=2
#
#
# after: https://web.archive.org/web/201902/http://streeteasy.com/for-rent/manhattan?page=9
#
#
# Scraped the following pages:  set()
#
# Which makes a total of : 0
# Pardon Our Interruption
# Page archived
# https://web.archive.org/web/20170809010827/http://streeteasy.com/building/the-hermitage/phb
#
# 13:53:38 Jul 30, 2017
#
#   price des_short des_rooms des_long amenities  zip  \
# 0   NaN       NaN       NaN      NaN       NaN  NaN
#
#                                              address last_price_change  \
# 0  As you were browsing, something about your bro...               NaN
#
#   days_on_market price_history lister price_at_point scrape_year scrape_day  \
# 0            NaN           NaN    NaN            NaN        2017         30
#
#   scrape_month scrape_hour
# 0          Jul    13:53:38
# Scraped:  5  out of : 10
#
#               Ready to see this place in person?
#
#               Get in touch with an agent.
#
# Page archived
# https://web.archive.org/web/20170809010827/http://streeteasy.com/building/647-east-14-street-new_york/0ma
#
#
# history_table:
#               0                                                  1         2
# 0   12/13/2013    Previously Listed by StuyTown Property Services    $3,549
# 1   12/20/2013  StuyTown Property Services Listing is no longe...    $3,549
# 2   04/08/2014    Previously Listed by StuyTown Property Services    $5,035
# 3   04/30/2014    Previously Listed by StuyTown Property Services    $4,840
# 4   04/30/2014  StuyTown Property Services Listing is no longe...    $4,840
# 5   05/22/2014  StuyTown Property Services Listing is no longe...    $4,790
# 6   02/16/2017    Previously Listed by StuyTown Property Services    $3,967
# 7   03/04/2017  StuyTown Property Services Listing is no longe...    $3,902
# 8   07/20/2017               Listed by StuyTown Property Services    $4,682
# 9   07/22/2017                              Price increased by 1%  ↑ $4,722
# 10  07/24/2017                              Price increased by 3%  ↑ $4,862
# 11  07/26/2017                              Price decreased by 2%  ↓ $4,757
# 12  07/27/2017                              Price decreased by 3%  ↓ $4,622
# 13  07/28/2017                              Price decreased by 1%  ↓ $4,592
# 14  07/29/2017                              Price decreased by 1%  ↓ $4,562
# 15  07/31/2017                              Price increased by 3%  ↑ $4,697
# 10:23:23 Aug 07, 2017
#
#     price                                      des_short  \
# 0  $4,697  943 ft², $59 per ft², 2 rooms, 3 beds, 1 bath
#
#                              des_rooms des_long  \
# 0  Rental Unit, in Stuyvesant Town/PCV      NaN
#
#                                  amenities  zip  \
# 0   \nBuilding  \nVirtual Doorman\n     \n  NaN
#
#                             address last_price_change days_on_market  \
# 0  \n\nComplex: Stuyvesant Town\n\n               NaN            NaN
#
#                                        price_history  \
# 0  12/13/2013|12/20/2013|04/08/2014|04/30/2014|04...
#
#                                               lister  \
# 0  Previously Listed by StuyTown Property Service...
#
#                                       price_at_point scrape_year scrape_day  \
# 0  $3,549|$3,549|$5,035|$4,840|$4,840|$4,790|$3,9...        2017         07
#
#   scrape_month scrape_hour
# 0          Aug    10:23:23
# Scraped:  5  out of : 10
# Hrm.
# Page not archived
# Scraped:  5  out of : 10
# Pardon Our Interruption
# Page archived
# https://web.archive.org/web/20170809010827/http://streeteasy.com/building/95-wall-street-new_york/518
#
# 13:55:11 Aug 13, 2017
#
#   price des_short des_rooms des_long amenities  zip  \
# 0   NaN       NaN       NaN      NaN       NaN  NaN
#
#                                              address last_price_change  \
# 0  As you were browsing, something about your bro...               NaN
#
#   days_on_market price_history lister price_at_point scrape_year scrape_day  \
# 0            NaN           NaN    NaN            NaN        2017         13
#
#   scrape_month scrape_hour
# 0          Aug    13:55:11
# Scraped:  5  out of : 10
# Pardon Our Interruption
# Page archived
# https://web.archive.org/web/20170809010827/http://streeteasy.com/building/95-wall-street-new_york/1519
#
# 12:36:53 Aug 13, 2017
#
#   price des_short des_rooms des_long amenities  zip  \
# 0   NaN       NaN       NaN      NaN       NaN  NaN
#
#                                              address last_price_change  \
# 0  As you were browsing, something about your bro...               NaN
#
#   days_on_market price_history lister price_at_point scrape_year scrape_day  \
# 0            NaN           NaN    NaN            NaN        2017         13
#
#   scrape_month scrape_hour
# 0          Aug    12:36:53
# Scraped:  5  out of : 10
# Listing Facts
# Page archived
# https://web.archive.org/web/20170809010827/http://streeteasy.com/building/95-wall-street-new_york/1007
#
#
# history_table:
#              0                                                  1         2
# 0  10/13/2013                           Previously Listed by UDR    $7,123
# 1  12/10/2013  UDR Listing is no longer available Last priced...    $7,941
# 2  11/06/2014                                      Listed by UDR    $5,659
# 3  12/10/2014                              Price decreased by 2%  ↓ $5,559
# 05:56:30 Dec 21, 2014
#
#     price                                des_short  \
# 0  $5,559  1,079 ft², $61 per ft², 2 beds, 2 baths
#
#                             des_rooms des_long  \
# 0  Rental Unit, in Financial District      NaN
#
#                                            amenities    zip         address  \
# 0   \nBuilding  \nBike Room\nConcierge\nDoorman\n...  10005  95 Wall Street
#
#              last_price_change         days_on_market  \
# 0  ↓ 1.77% 11 days ago by $100  45 days on StreetEasy
#
#                                  price_history  \
# 0  10/13/2013|12/10/2013|11/06/2014|12/10/2014
#
#                                               lister  \
# 0  Previously Listed by UDR|UDR Listing is no lon...
#
#                   price_at_point scrape_year scrape_day scrape_month  \
# 0  $7,123|$7,941|$5,659|↓ $5,559        2014         21          Dec
#
#   scrape_hour
# 0    05:56:30
# Scraped:  5  out of : 10
# Pardon Our Interruption
# Page archived
# https://web.archive.org/web/20170809010827/http://streeteasy.com/building/207-east-37-street-new_york/6
#
# 08:38:05 Aug 24, 2017
#
#   price des_short des_rooms des_long amenities  zip  \
# 0   NaN       NaN       NaN      NaN       NaN  NaN
#
#                                              address last_price_change  \
# 0  As you were browsing, something about your bro...               NaN
#
#   days_on_market price_history lister price_at_point scrape_year scrape_day  \
# 0            NaN           NaN    NaN            NaN        2017         24
#
#   scrape_month scrape_hour
# 0          Aug    08:38:05
# Scraped:  5  out of : 10
# Pardon Our Interruption
# Page archived
# https://web.archive.org/web/20170809010827/http://streeteasy.com/building/95-wall-street-new_york/523
#
# 06:45:04 Aug 17, 2017
#
#   price des_short des_rooms des_long amenities  zip  \
# 0   NaN       NaN       NaN      NaN       NaN  NaN
#
#                                              address last_price_change  \
# 0  As you were browsing, something about your bro...               NaN
#
#   days_on_market price_history lister price_at_point scrape_year scrape_day  \
# 0            NaN           NaN    NaN            NaN        2017         17
#
#   scrape_month scrape_hour
# 0          Aug    06:45:04
# Scraped:  5  out of : 10
# Pardon Our Interruption
# Page archived
# https://web.archive.org/web/20170809010827/http://streeteasy.com/building/790-9-avenue-new_york/4a
#
# 08:45:47 Aug 12, 2017
#
#   price des_short des_rooms des_long amenities  zip  \
# 0   NaN       NaN       NaN      NaN       NaN  NaN
#
#                                              address last_price_change  \
# 0  As you were browsing, something about your bro...               NaN
#
#   days_on_market price_history lister price_at_point scrape_year scrape_day  \
# 0            NaN           NaN    NaN            NaN        2017         12
#
#   scrape_month scrape_hour
# 0          Aug    08:45:47
# Scraped:  5  out of : 10
# Scraped:  5  out of : 10
# Building
# Page archived
# https://web.archive.org/web/20170809010827/http://streeteasy.com/building/784-columbus-avenue-new_york/14k
#
# 01:46:31 Sep 30, 2016
#
#   price des_short des_rooms des_long amenities    zip               address  \
# 0   NaN       NaN       NaN      NaN       NaN  10025   784 Columbus Avenue
#
#   last_price_change days_on_market price_history lister price_at_point  \
# 0               NaN            NaN           NaN    NaN            NaN
#
#   scrape_year scrape_day scrape_month scrape_hour
# 0        2016         30          Sep    01:46:31
# Scraped:  5  out of : 10
# Pardon Our Interruption
# Page archived
# https://web.archive.org/web/20170809010827/http://streeteasy.com/building/soho-court/1007
#
# 08:50:08 Aug 12, 2017
#
#   price des_short des_rooms des_long amenities  zip  \
# 0   NaN       NaN       NaN      NaN       NaN  NaN
#
#                                              address last_price_change  \
# 0  As you were browsing, something about your bro...               NaN
#
#   days_on_market price_history lister price_at_point scrape_year scrape_day  \
# 0            NaN           NaN    NaN            NaN        2017         12
#
#   scrape_month scrape_hour
# 0          Aug    08:50:08
# Scraped:  5  out of : 10
# Scraped:  5  out of : 10
# Pardon Our Interruption
# Page archived
# https://web.archive.org/web/20170809010827/http://streeteasy.com/building/319-east-53-street-new_york/2f
#
# 05:05:49 Aug 12, 2017
#
#   price des_short des_rooms des_long amenities  zip  \
# 0   NaN       NaN       NaN      NaN       NaN  NaN
#
#                                              address last_price_change  \
# 0  As you were browsing, something about your bro...               NaN
#
#   days_on_market price_history lister price_at_point scrape_year scrape_day  \
# 0            NaN           NaN    NaN            NaN        2017         12
#
#   scrape_month scrape_hour
# 0          Aug    05:05:49
# Scraped:  5  out of : 10
#
# Looking into:  6
#
#  https://web.archive.org/web/201902/http://streeteasy.com/for-rent/manhattan?page=9
#
#
# after: https://web.archive.org/web/201902/http://streeteasy.com/for-rent/manhattan?page=6
#
#
# Scraped the following pages:  {9}
#
# Which makes a total of : 1
#
# Looking into:  8
#
#  https://web.archive.org/web/201902/http://streeteasy.com/for-rent/manhattan?page=6
#
#
# after: https://web.archive.org/web/201902/http://streeteasy.com/for-rent/manhattan?page=8
#
#
# Scraped the following pages:  {9}
#
# Which makes a total of : 1
# Listing Facts
# Page archived
# https://web.archive.org/web/20161021052141/http://streeteasy.com/building/the-colorado/12a?featured=1
#
#
# history_table:
#              0                               1         2
# 0  07/22/2016      Listed by Nancy Packes Inc    $5,623
# 1  07/29/2016  Listing is no longer available    $5,623
# 2  10/06/2016   Re-listed by Nancy Packes Inc    $6,610
# 3  10/06/2016          Price increased by 18%  ↑ $6,610
# 00:56:06 Oct 26, 2016
#
#     price                 des_short                  des_rooms  \
# 0  $6,610  4 rooms, 2 beds, 2 baths  Rental Unit, in Yorkville
#
#                                             des_long  \
# 0  \n  Includes 2 months free on a 14 month lease...
#
#                                            amenities    zip  \
# 0  \nHighlights    Doorman            This highli...  10028
#
#                              address             last_price_change  \
# 0  The Colorado 201 East 86th Street  ↑ 12.99% 19 days ago by $987
#
#           days_on_market                                price_history  \
# 0  26 days on StreetEasy  07/22/2016|07/29/2016|10/06/2016|10/06/2016
#
#                                               lister  \
# 0  Listed by Nancy Packes Inc|Listing is no longe...
#
#                   price_at_point scrape_year scrape_day scrape_month  \
# 0  $5,623|$5,623|$6,610|↑ $6,610        2016         26          Oct
#
#   scrape_hour
# 0    00:56:06
# Scraped:  7  out of : 10
# Hrm.
# Page not archived
# Scraped:  7  out of : 10
# Hrm.
# Page not archived
# Scraped:  7  out of : 10
# Hrm.
# Page not archived
# Scraped:  7  out of : 10
# Hrm.
# Page not archived
# Scraped:  7  out of : 10
# Listing Facts
# Page archived
# https://web.archive.org/web/20161021052141/http://streeteasy.com/building/309-west-30-street-new_york/7d
#
#
# history_table:
#              0                                                  1         2
# 0  03/30/2012            Previously Listed by B and L Management    $1,985
# 1  04/10/2012  B and L Management Listing is no longer available    $1,985
# 2  04/30/2013            Previously Listed by B and L Management    $2,150
# 3  06/10/2013  B and L Management Listing is no longer available    $2,150
# 4  10/20/2016                       Previously Listed by Compass    $2,750
# 5  11/21/2016             Compass Listing is no longer available    $2,750
# 6  11/22/2016                                      Listed by MNS    $3,022
# 7  12/07/2016                              Price increased by 2%  ↑ $3,069
# 13:56:36 Jan 06, 2017
#
#     price       des_short                     des_rooms  \
# 0  $3,069  studio, 1 bath  Rental Unit, in Hudson Yards
#
#                                             des_long  \
# 0  \n  *NO FEE, ONE MONTH FREESpacious Studio - C...
#
#                                           amenities    zip  \
# 0  \nHighlights            Pets Allowed \n           10001
#
#                  address last_price_change         days_on_market  \
# 0   309 West 30th Street               NaN  45 days on StreetEasy
#
#                                        price_history  \
# 0  03/30/2012|04/10/2012|04/30/2013|06/10/2013|10...
#
#                                               lister  \
# 0  Previously Listed by B and L Management|B and ...
#
#                                       price_at_point scrape_year scrape_day  \
# 0  $1,985|$1,985|$2,150|$2,150|$2,750|$2,750|$3,0...        2017         06
#
#   scrape_month scrape_hour
# 0          Jan    13:56:36
# Scraped:  7  out of : 10
# Hrm.
# Page not archived
# Scraped:  7  out of : 10
# Listing Facts
# Page archived
# https://web.archive.org/web/20161021052141/http://streeteasy.com/building/434-lenox-avenue-manhattan/3a
#
#
# history_table:
#              0                                                  1       2
# 0  05/18/2016           Previously Listed by Keller Williams NYC  $2,700
# 1  09/20/2016                      Listed by Keller Williams NYC  $2,650
# 2  09/20/2016  Keller Williams NYC Listing is no longer avail...  $2,700
# 18:53:35 Oct 18, 2016
#
#     price                des_short                       des_rooms des_long  \
# 0  $2,650  4 rooms, 2 beds, 1 bath  Rental Unit, in Central Harlem      NaN
#
#                                   amenities    zip            address  \
# 0  \nHighlights    Washer/Dryer In-Unit  \n  10037   434 Lenox Avenue
#
#   last_price_change         days_on_market                     price_history  \
# 0               NaN  28 days on StreetEasy  05/18/2016|09/20/2016|09/20/2016
#
#                                               lister        price_at_point  \
# 0  Previously Listed by Keller Williams NYC|Liste...  $2,700|$2,650|$2,700
#
#   scrape_year scrape_day scrape_month scrape_hour
# 0        2016         18          Oct    18:53:35
# Scraped:  7  out of : 10
# Hrm.
# Page not archived
# Scraped:  7  out of : 10
# Listing Facts
# Page archived
# https://web.archive.org/web/20161021052141/http://streeteasy.com/building/226-east-12-street-new_york/rental/1913953
#
#
# history_table:
#              0                                                  1       2
# 0  01/28/2009          Previously Listed by Brown Harris Stevens  $2,300
# 1  04/07/2009       Off market temporarily Last priced at $2,400  $2,100
# 2  10/07/2009          Previously Listed by Brown Harris Stevens  $2,400
# 3  02/08/2010  Brown Harris Stevens Listing rented Last price...  $1,800
# 4  08/19/2016                       Also Listed by Bond New York  $2,950
# 5  08/31/2016           Previously Listed by Keller Williams NYC  $2,950
# 6  10/20/2016                      Listed by Keller Williams NYC  $2,849
# 7  10/20/2016  Keller Williams NYC Listing is no longer avail...  $2,849
# 01:35:17 Oct 26, 2016
#
#     price               des_short               des_rooms des_long  \
# 0  $2,849  3 rooms, 1 bed, 1 bath  Co-op, in East Village      NaN
#
#                                            amenities    zip  \
# 0  \nHighlights    Cats and Dogs Allowed         ...  10003
#
#                  address last_price_change        days_on_market  \
# 0   226 East 12th Street               NaN  5 days on StreetEasy
#
#                                        price_history  \
# 0  01/28/2009|04/07/2009|10/07/2009|02/08/2010|08...
#
#                                               lister  \
# 0  Previously Listed by Brown Harris Stevens|Off ...
#
#                                       price_at_point scrape_year scrape_day  \
# 0  $2,300|$2,100|$2,400|$1,800|$2,950|$2,950|$2,8...        2016         26
#
#   scrape_month scrape_hour
# 0          Oct    01:35:17
# Scraped:  7  out of : 10
# ...
# 0  $3,549|$3,549|$5,035|$4,840|$4,840|$4,790|$3,9...        2017         07
#
#   scrape_month scrape_hour
# 0          Aug    10:23:23
# Scraped:  2  out of : 10
# Hrm.
# Page not archived
# Scraped:  2  out of : 10
# Pardon Our Interruption
# Page archived
# https://web.archive.org/web/20170809010827/http://streeteasy.com/building/95-wall-street-new_york/518
#
# 13:55:11 Aug 13, 2017
#
#   price des_short des_rooms des_long amenities  zip  \
# 0   NaN       NaN       NaN      NaN       NaN  NaN
#
#                                              address last_price_change  \
# 0  As you were browsing, something about your bro...               NaN
#
#   days_on_market price_history lister price_at_point scrape_year scrape_day  \
# 0            NaN           NaN    NaN            NaN        2017         13
#
#   scrape_month scrape_hour
# 0          Aug    13:55:11
# Scraped:  2  out of : 10
# Pardon Our Interruption
# Page archived
# https://web.archive.org/web/20170809010827/http://streeteasy.com/building/95-wall-street-new_york/1519
#
# 12:36:53 Aug 13, 2017
#
#   price des_short des_rooms des_long amenities  zip  \
# 0   NaN       NaN       NaN      NaN       NaN  NaN
#
#                                              address last_price_change  \
# 0  As you were browsing, something about your bro...               NaN
#
#   days_on_market price_history lister price_at_point scrape_year scrape_day  \
# 0            NaN           NaN    NaN            NaN        2017         13
#
#   scrape_month scrape_hour
# 0          Aug    12:36:53
# Scraped:  2  out of : 10
# Listing Facts
# Page archived
# https://web.archive.org/web/20170809010827/http://streeteasy.com/building/95-wall-street-new_york/1007
#
#
# history_table:
#              0                                                  1         2
# 0  10/13/2013                           Previously Listed by UDR    $7,123
# 1  12/10/2013  UDR Listing is no longer available Last priced...    $7,941
# 2  11/06/2014                                      Listed by UDR    $5,659
# 3  12/10/2014                              Price decreased by 2%  ↓ $5,559
# 05:56:30 Dec 21, 2014
#
#     price                                des_short  \
# 0  $5,559  1,079 ft², $61 per ft², 2 beds, 2 baths
#
#                             des_rooms des_long  \
# 0  Rental Unit, in Financial District      NaN
#
#                                            amenities    zip         address  \
# 0   \nBuilding  \nBike Room\nConcierge\nDoorman\n...  10005  95 Wall Street
#
#              last_price_change         days_on_market  \
# 0  ↓ 1.77% 11 days ago by $100  45 days on StreetEasy
#
#                                  price_history  \
# 0  10/13/2013|12/10/2013|11/06/2014|12/10/2014
#
#                                               lister  \
# 0  Previously Listed by UDR|UDR Listing is no lon...
#
#                   price_at_point scrape_year scrape_day scrape_month  \
# 0  $7,123|$7,941|$5,659|↓ $5,559        2014         21          Dec
#
#   scrape_hour
# 0    05:56:30
# Scraped:  2  out of : 10
# Pardon Our Interruption
# Page archived
# https://web.archive.org/web/20170809010827/http://streeteasy.com/building/207-east-37-street-new_york/6
#
# 08:38:05 Aug 24, 2017
#
#   price des_short des_rooms des_long amenities  zip  \
# 0   NaN       NaN       NaN      NaN       NaN  NaN
#
#                                              address last_price_change  \
# 0  As you were browsing, something about your bro...               NaN
#
#   days_on_market price_history lister price_at_point scrape_year scrape_day  \
# 0            NaN           NaN    NaN            NaN        2017         24
#
#   scrape_month scrape_hour
# 0          Aug    08:38:05
# Scraped:  2  out of : 10
# Pardon Our Interruption
# Page archived
# https://web.archive.org/web/20170809010827/http://streeteasy.com/building/95-wall-street-new_york/523
#
# 06:45:04 Aug 17, 2017
#
#   price des_short des_rooms des_long amenities  zip  \
# 0   NaN       NaN       NaN      NaN       NaN  NaN
#
#                                              address last_price_change  \
# 0  As you were browsing, something about your bro...               NaN
#
#   days_on_market price_history lister price_at_point scrape_year scrape_day  \
# 0            NaN           NaN    NaN            NaN        2017         17
#
#   scrape_month scrape_hour
# 0          Aug    06:45:04
# Scraped:  2  out of : 10
# Pardon Our Interruption
# Page archived
# https://web.archive.org/web/20170809010827/http://streeteasy.com/building/790-9-avenue-new_york/4a
#
# 08:45:47 Aug 12, 2017
#
#   price des_short des_rooms des_long amenities  zip  \
# 0   NaN       NaN       NaN      NaN       NaN  NaN
#
#                                              address last_price_change  \
# 0  As you were browsing, something about your bro...               NaN
#
#   days_on_market price_history lister price_at_point scrape_year scrape_day  \
# 0            NaN           NaN    NaN            NaN        2017         12
#
#   scrape_month scrape_hour
# 0          Aug    08:45:47
# Scraped:  2  out of : 10
# Scraped:  2  out of : 10
# Building
# Page archived
# https://web.archive.org/web/20170809010827/http://streeteasy.com/building/784-columbus-avenue-new_york/14k
#
# 01:46:31 Sep 30, 2016
#
#   price des_short des_rooms des_long amenities    zip               address  \
# 0   NaN       NaN       NaN      NaN       NaN  10025   784 Columbus Avenue
#
#   last_price_change days_on_market price_history lister price_at_point  \
# 0               NaN            NaN           NaN    NaN            NaN
#
#   scrape_year scrape_day scrape_month scrape_hour
# 0        2016         30          Sep    01:46:31
# Scraped:  2  out of : 10
# Pardon Our Interruption
# Page archived
# https://web.archive.org/web/20170809010827/http://streeteasy.com/building/soho-court/1007
#
# 08:50:08 Aug 12, 2017
#
#   price des_short des_rooms des_long amenities  zip  \
# 0   NaN       NaN       NaN      NaN       NaN  NaN
#
#                                              address last_price_change  \
# 0  As you were browsing, something about your bro...               NaN
#
#   days_on_market price_history lister price_at_point scrape_year scrape_day  \
# 0            NaN           NaN    NaN            NaN        2017         12
#
#   scrape_month scrape_hour
# 0          Aug    08:50:08
# Scraped:  2  out of : 10
# Scraped:  2  out of : 10
# Pardon Our Interruption
# Page archived
# https://web.archive.org/web/20170809010827/http://streeteasy.com/building/319-east-53-street-new_york/2f
#
# 05:05:49 Aug 12, 2017
#
#   price des_short des_rooms des_long amenities  zip  \
# 0   NaN       NaN       NaN      NaN       NaN  NaN
#
#                                              address last_price_change  \
# 0  As you were browsing, something about your bro...               NaN
#
#   days_on_market price_history lister price_at_point scrape_year scrape_day  \
# 0            NaN           NaN    NaN            NaN        2017         12
#
#   scrape_month scrape_hour
# 0          Aug    05:05:49
# Scraped:  2  out of : 10
#
# Looking into:  7
#
#  https://web.archive.org/web/201912/http://streeteasy.com/for-rent/manhattan?page=9
#
#
# after: https://web.archive.org/web/201912/http://streeteasy.com/for-rent/manhattan?page=7
#
#
# Scraped the following pages:  {9}
#
# Which makes a total of : 1
#
# Looking into:  6
#
#  https://web.archive.org/web/201912/http://streeteasy.com/for-rent/manhattan?page=7
#
#
# after: https://web.archive.org/web/201912/http://streeteasy.com/for-rent/manhattan?page=6
#
#
# Scraped the following pages:  {9}
#
# Which makes a total of : 1
#
# Looking into:  4
#
#  https://web.archive.org/web/201912/http://streeteasy.com/for-rent/manhattan?page=6
#
#
# after: https://web.archive.org/web/201912/http://streeteasy.com/for-rent/manhattan?page=4
#
#
# Scraped the following pages:  {9}
#
# Which makes a total of : 1
#
# Looking into:  2
#
#  https://web.archive.org/web/201912/http://streeteasy.com/for-rent/manhattan?page=4
#
#
# after: https://web.archive.org/web/201912/http://streeteasy.com/for-rent/manhattan?page=2
#
#
# Scraped the following pages:  {9}
#
# Which makes a total of : 1
#
# Looking into:  5
#
#  https://web.archive.org/web/201912/http://streeteasy.com/for-rent/manhattan?page=2
#
#
# after: https://web.archive.org/web/201912/http://streeteasy.com/for-rent/manhattan?page=5
#
#
# Scraped the following pages:  {9}
#
# Which makes a total of : 1
#
# Looking into:  3
#
#  https://web.archive.org/web/201912/http://streeteasy.com/for-rent/manhattan?page=5
#
#
# after: https://web.archive.org/web/201912/http://streeteasy.com/for-rent/manhattan?page=3
#
#
# Scraped the following pages:  {9}
#
# Which makes a total of : 1
#
# Looking into:  10
#
#  https://web.archive.org/web/201912/http://streeteasy.com/for-rent/manhattan?page=3
#
#
# after: https://web.archive.org/web/201912/http://streeteasy.com/for-rent/manhattan?page=10
#
#
# Scraped the following pages:  {9}
#
# Which makes a total of : 1
# Hrm.
# Page not archived
# Scraped:  9  out of : 10
# Pardon Our Interruption
# Page archived
# https://web.archive.org/web/20170702183051/http://streeteasy.com/building/city-and-suburban-homes-company-av-519-east-78-street-new_york/1g
#
# 02:48:13 Jul 02, 2017
#
#   price des_short des_rooms des_long amenities  zip  \
# 0   NaN       NaN       NaN      NaN       NaN  NaN
#
#                                              address last_price_change  \
# 0  As you were browsing, something about your bro...               NaN
#
#   days_on_market price_history lister price_at_point scrape_year scrape_day  \
# 0            NaN           NaN    NaN            NaN        2017         02
#
#   scrape_month scrape_hour
# 0          Jul    02:48:13
# Scraped:  9  out of : 10
# Pardon Our Interruption
# Page archived
# https://web.archive.org/web/20170702183051/http://streeteasy.com/building/517-east-77-street-/2l
#
# 06:03:02 Jul 09, 2017
#
#   price des_short des_rooms des_long amenities  zip  \
# 0   NaN       NaN       NaN      NaN       NaN  NaN
#
#                                              address last_price_change  \
# 0  As you were browsing, something about your bro...               NaN
#
#   days_on_market price_history lister price_at_point scrape_year scrape_day  \
# 0            NaN           NaN    NaN            NaN        2017         09
#
#   scrape_month scrape_hour
# 0          Jul    06:03:02
# Scraped:  9  out of : 10
# Hrm.
# Page not archived
# Scraped:  9  out of : 10
# Hrm.
# Page not archived
# Scraped:  9  out of : 10
# Pardon Our Interruption
# Page archived
# https://web.archive.org/web/20170702183051/http://streeteasy.com/building/new-york-tower/10k
#
# 06:25:13 Jul 09, 2017
#
#   price des_short des_rooms des_long amenities  zip  \
# 0   NaN       NaN       NaN      NaN       NaN  NaN
#
#                                              address last_price_change  \
# 0  As you were browsing, something about your bro...               NaN
#
#   days_on_market price_history lister price_at_point scrape_year scrape_day  \
# 0            NaN           NaN    NaN            NaN        2017         09
#
#   scrape_month scrape_hour
# 0          Jul    06:25:13
# Scraped:  9  out of : 10
# Pardon Our Interruption
# Page archived
# https://web.archive.org/web/20170702183051/http://streeteasy.com/building/new-york-tower/29e
#
# 04:44:45 Jul 09, 2017
#
#   price des_short des_rooms des_long amenities  zip  \
# 0   NaN       NaN       NaN      NaN       NaN  NaN
#
#                                              address last_price_change  \
# 0  As you were browsing, something about your bro...               NaN
#
#   days_on_market price_history lister price_at_point scrape_year scrape_day  \
# 0            NaN           NaN    NaN            NaN        2017         09
#
#   scrape_month scrape_hour
# 0          Jul    04:44:45
# Scraped:  9  out of : 10
# Pardon Our Interruption
# Page archived
# https://web.archive.org/web/20170702183051/http://streeteasy.com/building/new-york-tower/31m
#
# 08:05:05 Jul 17, 2017
#
#   price des_short des_rooms des_long amenities  zip  \
# 0   NaN       NaN       NaN      NaN       NaN  NaN
#
#                                              address last_price_change  \
# 0  As you were browsing, something about your bro...               NaN
#
#   days_on_market price_history lister price_at_point scrape_year scrape_day  \
# 0            NaN           NaN    NaN            NaN        2017         17
#
#   scrape_month scrape_hour
# 0          Jul    08:05:05
# Scraped:  9  out of : 10
# Hrm.
# Page not archived
# Scraped:  9  out of : 10
# Listing Facts
# Page archived
# https://web.archive.org/web/20170702183051/http://streeteasy.com/building/biltmore-plaza/29c
#
#
# history_table:
#              0                               1         2
# 0  04/18/2013      Previously Listed by Ogden    $3,610
# 1  05/09/2013            Ogden Listing rented    $3,610
# 2  06/25/2015  Listed by Ogden CAP Properties    $4,230
# 3  06/26/2015           Price decreased by 0%  ↓ $4,225
# 22:17:08 Jun 26, 2015
#
#     price                            des_short                 des_rooms  \
# 0  $4,225  591 ft², $85 per ft², 1 bed, 1 bath  Rental Unit, in Kips Bay
#
#   des_long                                          amenities    zip  \
# 0      NaN   \nBuilding  \nDoorman\nElevator\nGarage Parki...  10016
#
#                                address         last_price_change  \
# 0  Biltmore Plaza 155 East 29th Street  ↓ 0.12% 0 days ago by $5
#
#   days_on_market                                price_history  \
# 0            NaN  04/18/2013|05/09/2013|06/25/2015|06/26/2015
#
#                                               lister  \
# 0  Previously Listed by Ogden|Ogden Listing rente...
#
#                   price_at_point scrape_year scrape_day scrape_month  \
# 0  $3,610|$3,610|$4,230|↓ $4,225        2015         26          Jun
#
#   scrape_hour
# 0    22:17:08
# Scraped:  9  out of : 10
# Hrm.
# Page not archived
# Scraped:  9  out of : 10
# Pardon Our Interruption
# Page archived
# https://web.archive.org/web/20170702183051/http://streeteasy.com/building/399-east-78-street-new_york/5c
#
# 12:44:58 Jul 07, 2017
#
#   price des_short des_rooms des_long amenities  zip  \
# 0   NaN       NaN       NaN      NaN       NaN  NaN
#
#                                              address last_price_change  \
# 0  As you were browsing, something about your bro...               NaN
#
#   days_on_market price_history lister price_at_point scrape_year scrape_day  \
# 0            NaN           NaN    NaN            NaN        2017         07
#
#   scrape_month scrape_hour
# 0          Jul    12:44:58
# Scraped:  9  out of : 10
# Pardon Our Interruption
# Page archived
# https://web.archive.org/web/20170702183051/http://streeteasy.com/building/38nine-condominium/4c
#
# 01:46:36 Jul 09, 2017
#
#   price des_short des_rooms des_long amenities  zip  \
# 0   NaN       NaN       NaN      NaN       NaN  NaN
#
#                                              address last_price_change  \
# 0  As you were browsing, something about your bro...               NaN
#
#   days_on_market price_history lister price_at_point scrape_year scrape_day  \
# 0            NaN           NaN    NaN            NaN        2017         09
#
#   scrape_month scrape_hour
# 0          Jul    01:46:36
# Scraped:  9  out of : 10
# Pardon Our Interruption
# Page archived
# https://web.archive.org/web/20170702183051/http://streeteasy.com/building/87-bowery-new_york/702
#
# 01:39:29 Jul 26, 2017
#
#   price des_short des_rooms des_long amenities  zip  \
# 0   NaN       NaN       NaN      NaN       NaN  NaN
#
#                                              address last_price_change  \
# 0  As you were browsing, something about your bro...               NaN
#
#   days_on_market price_history lister price_at_point scrape_year scrape_day  \
# 0            NaN           NaN    NaN            NaN        2017         26
#
#   scrape_month scrape_hour
# 0          Jul    01:39:29
# Scraped:  9  out of : 10
#
# Looking into:  8
#
#  https://web.archive.org/web/201912/http://streeteasy.com/for-rent/manhattan?page=10
#
#
# after: https://web.archive.org/web/201912/http://streeteasy.com/for-rent/manhattan?page=8
#
#
# Scraped the following pages:  {9, 10}
#
# Which makes a total of : 2
